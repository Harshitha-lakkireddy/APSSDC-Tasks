# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python39\site-packages (1.3.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (2021.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\program files\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\program files\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)

# %%
import pandas as pd

# %%
# Step 3. Use the Csv file and assign it to a dataframe called birds 
birds = pd.read_csv("https://raw.githubusercontent.com/Ramadevi-damarla/AP19110010386_Ramadevi_APSSDC_Internship/main/bird.csv")
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ..   ...
# 415   SO
# 416   SO
# 417   SO
# 418   SO
# 419   SO
#
# [420 rows x 12 columns]

# %%
# Step 4. See the random 5 entries
birds.sample(5)
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 113  113  76.49  5.36  69.06   4.02  30.07  3.03  72.41  3.71  43.11  2.08
# 67    67  32.47  1.94  31.74   1.78  14.37  1.23  33.29  1.17  20.79  1.09
# 85    85  89.59  5.11  98.02   4.46  29.96  2.55  58.09  2.79  34.40  2.94
# 122  122  67.63  4.37  60.17   3.73  53.03  4.08  92.18  4.31  54.38  4.14
# 79    79  54.19  3.16  54.28   3.21  23.08  1.98  53.70  2.04  31.29  1.56
#
#     type
# 113   SW
# 67    SW
# 85    SW
# 122    W
# 79    SW

# %%
# Step 5. What is the number of observations in the dataset?
len(birds.index)
# Out:
# 420

# %%
# Step 6. What is the number of columns in the dataset?
len(birds.columns)
# Out:
# 12

# %%
# Step 7. Print the name of all the columns.
birds.columns
# Out:
# Index(['id', 'huml', 'humw', 'ulnal', 'ulnaw', 'feml', 'femw', 'tibl', 'tibw',
#        'tarl', 'tarw', 'type'],
#       dtype='object')

# %%
# Step 8. What is the name of 10th column?
birds.columns[9]
# Out:
# 'tarl'

# %%
# Step 9. What is the type of the observations of the 2th column?
birds.dtypes[2]
# Out:
# dtype('float64')

# %%
# Step 10. How is the dataset indexed?
birds.index
# Out:
# RangeIndex(start=0, stop=420, step=1)

# %%
# Step 11. Set the 'type' colum as the index of the dataframe
birds.set_index("type")
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SW      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# SW      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# SW      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# SW      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ...   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# SO    415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# SO    416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# SO    417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# SO    418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
# [420 rows x 11 columns]

# %%
# Step 12. Print only the column huml
print(birds["huml"])
# Out:
# 0      80.78
# 1      88.91
# 2      79.97
# 3      77.65
# 4      62.80
#        ...
# 415    17.96
# 416    19.21
# 417    18.79
# 418    20.38
# 419    17.89
# Name: huml, Length: 420, dtype: float64

# %%
# Step 13. Print the "huml","humw" columns from SW and P
birds[(birds["type"]=="SW") | (birds["type"]=="P")]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 287  287  27.72  2.67  32.00   2.21  22.68  2.13  32.50  1.76  19.65  1.64
# 288  288  29.14  2.75  32.91   2.16  23.13  2.11  33.89  1.80  20.86  1.70
# 289  289  27.85  2.65  32.62   2.05  22.84  2.14  33.62  1.91  20.82  1.80
# 290  290  20.06  1.73  23.15   1.49  16.63  1.57  24.71  1.29  15.19  1.24
# 291  291  41.60  3.74  56.50   3.02  37.00  2.99  62.90  2.82  38.21  2.51
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ..   ...
# 287    P
# 288    P
# 289    P
# 290    P
# 291    P
#
# [154 rows x 12 columns]

# %%
# Step 14. Select the rows 3 to 7 and the columns 3 to 6
birds.iloc[3:8, 3:7]
# Out:
#    ulnal  ulnaw   feml  femw
# 3  65.76   4.77  40.04  3.52
# 4  52.09   3.73  33.95  2.72
# 5  50.46   3.47  49.52  4.41
# 6  67.39   4.50  42.07  3.41
# 7  74.52   4.55  44.46  3.78

# %%
# Step 15. Select rows where df.femw is greater than 5.2 or less than 10.5
birds[(birds["femw"] > 5.2) | (birds["femw"] < 10.5)]
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ..   ...
# 415   SO
# 416   SO
# 417   SO
# 418   SO
# 419   SO
#
# [419 rows x 12 columns]

# %%
# Step 16. Select the third cell down in the column named tarl
birds.loc[3,"tarl"]
# Out:
# 35.78

# %%
# Step 17. Compute how many values are non-missing for each feature over the entire record.
birds.notnull().sum()
# Out:
# id       420
# huml     419
# humw     419
# ulnal    417
# ulnaw    418
# feml     418
# femw     419
# tibl     418
# tibw     419
# tarl     419
# tarw     419
# type     420
# dtype: int64

# %%
# Step18. Calculate Mean and Median of "tibl" and "tibw" columns
birds[["tibl","tibw"]].agg(["mean","median"])
# Out:
#              tibl      tibw
# mean    64.662823  3.182339
# median  52.120000  2.490000

# %%
# Step19. Discover what is the mean "ulnaw" per every bird category (use Groupby)
birds.groupby('type')[['ulnaw']].mean()
# Out:
#          ulnaw
# type
# P     2.476316
# R     4.813265
# SO    1.743858
# SW    5.221638
# T     3.471739
# W     4.102615

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp39-cp39-win_amd64.whl (7.1 MB)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp39-cp39-win_amd64.whl (51 kB)
# Requirement already satisfied: numpy>=1.16 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\program files\python39\lib\site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\program files\python39\lib\site-packages (from matplotlib) (2.4.7)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.3.1-1-cp39-cp39-win_amd64.whl (3.2 MB)
# Requirement already satisfied: six in c:\program files\python39\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 pillow-8.3.1

# %%
# Step20. Plot graph between all features refuse "type" and "id" columns
import matplotlib.pyplot as plt
plot = ['type', 'id']
birds.loc[:, birds.columns.difference(plot)].hist()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

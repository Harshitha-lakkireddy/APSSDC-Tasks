# %%
#Task 1
#Relace null values in 'Age' column with ffill()
#Replace null values in cabin and embarked colmn wiht most occured value

# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/nagamounika5/Datasets/master/titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.isnull().sum().sum()
# Out:
# 866

# %%
# Relace null values in 'Age' column with ffill()
titanic['Age'].fillna(method = "ffill", inplace = True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Replace null values in cabin and embarked colmn wiht most occured value
titanic['Cabin'].fillna(titanic['Cabin'].mode().iloc[0], inplace = True)
titanic['Embarked'].fillna(titanic['Embarked'].mode().iloc[0], inplace = True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#Task 2:
#After handiling missing values. convert cabin , embarked columns into numberical columns

from sklearn.preprocessing import LabelEncoder
nu=LabelEncoder()

# %%
# !pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
# ...
# Using legacy 'setup.py install' for sklearn, since package 'wheel' is not installed.
# ...
#     Running setup.py install for sklearn: started
#     Running setup.py install for sklearn: finished with status 'done'
# ...

# %%
titanic['Cabin'] = nu.fit_transform(titanic['Cabin'])
titanic['Embarked'] = nu.fit_transform(titanic['Embarked'])
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Task 3:
#Display the plot of original data and robust scaler data¶
import matplotlib.pyplot as plt
titanic.plot(kind = 'hist')
plt.show()

# %%
from sklearn.preprocessing import RobustScaler

# %%
titanic['Cabin'] = nu.fit_transform(titanic['Cabin'])
titanic['Embarked'] = nu.fit_transform(titanic['Embarked'])
titanic['Name'] = nu.fit_transform(titanic['Name'])
titanic['Sex'] = nu.fit_transform(titanic['Sex'])
titanic['Ticket'] = nu.fit_transform(titanic['Ticket'])
titanic
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              1         0       3   108    1  22.0      1      0     523
# 1              2         1       1   190    0  38.0      1      0     596
# 2              3         1       3   353    0  26.0      0      0     669
# 3              4         1       1   272    0  35.0      1      0      49
# 4              5         0       3    15    1  35.0      0      0     472
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          887         0       2   548    1  27.0      0      0     101
# 887          888         1       1   303    0  19.0      0      0      14
# 888          889         0       3   413    0  19.0      1      2     675
# 889          890         1       1    81    1  26.0      0      0       8
# 890          891         0       3   220    1  32.0      0      0     466
#
#         Fare  Cabin  Embarked
# 0     7.2500     47         2
# ...

# %%
rs = RobustScaler()
rs1 = rs.fit_transform(titanic)
rs2 = pd.DataFrame(rs1, columns = titanic.columns)
rs2.plot(kind = 'hist')
plt.show()
